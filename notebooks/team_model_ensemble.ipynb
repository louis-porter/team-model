# %%
import numpy as np
import pandas as pd
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args
from skopt.plots import plot_convergence, plot_objective
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))
from models.standard_dc import StandardTeamModel
from models.psxg_shots_resimmed_dc import PSxGShotsTeamModel
from models.psxg_totals_resimmed_dc import PSxGTotalTeamModel
from models.xg_shots_resimmed_dc import xGShotsTeamModel
from models.xg_totals_resimmed_dc import xGTotalTeamModel
from data.fetch_match_data import load_data

# %%
class EnsembleTeamModel:
    def __init__(self, models=None, model_weights=None):
        """
        Initialize the ensemble model with individual models and their weights.
        
        Parameters:
        models: Dictionary mapping model names to model instances
        model_weights: Dictionary mapping model names to weights
        """
        self.models = models or {}
        self.weights = model_weights or {
            'standard': 0.2,
            'psxg_shots': 0.2,
            'psxg_total': 0.2, 
            'xg_shots': 0.2,
            'xg_total': 0.2
        }
        self.team_attack = {}
        self.team_defense = {}
        self.home_advantage = 0.0
        self.rho = 0.0
        
    def add_model(self, name, model):
        """Add a model to the ensemble."""
        self.models[name] = model
        return self
        
    def combine_parameters(self):
        """Combine parameters from all models based on weights."""
        # Normalize weights to ensure they sum to 1
        total_weight = sum(self.weights.values())
        normalized_weights = {k: v/total_weight for k, v in self.weights.items()}
        
        # Ensure we have all required models
        for name in normalized_weights:
            if name not in self.models:
                raise ValueError(f"Model '{name}' was weighted but not added to the ensemble")
        
        # Get all unique teams across models
        all_teams = set()
        for model_name, model in self.models.items():
            all_teams.update(model.team_attack.keys())
        
        # Initialize combined parameters
        combined_attack = {team: 0.0 for team in all_teams}
        combined_defense = {team: 0.0 for team in all_teams}
        combined_home_advantage = 0.0
        combined_rho = 0.0
        
        # Combine parameters
        for model_name, model in self.models.items():
            weight = normalized_weights.get(model_name, 0.0)
            if weight <= 0:
                continue
                
            # Combine team attack and defense
            for team in all_teams:
                if team in model.team_attack:
                    combined_attack[team] += model.team_attack[team] * weight
                if team in model.team_defense:
                    combined_defense[team] += model.team_defense[team] * weight
            
            # Combine scalar parameters
            combined_home_advantage += model.home_advantage * weight
            combined_rho += model.rho * weight
        
        # Update the ensemble model's parameters
        self.team_attack = combined_attack
        self.team_defense = combined_defense
        self.home_advantage = combined_home_advantage
        self.rho = combined_rho
        
        return self
    
    def predict_match(self, home_team, away_team, max_goals=10):
        """Predict match outcome using the ensemble model."""
        # Check if parameters have been combined
        if not self.team_attack or not self.team_defense:
            self.combine_parameters()
            
        # Check if teams exist in the model
        if home_team not in self.team_attack or away_team not in self.team_attack:
            raise ValueError(f"Teams not found in the ensemble model. Available teams: {sorted(self.team_attack.keys())}")
        
        # Calculate expected goals from ensemble model
        lambda_home = self.team_attack[home_team] * self.team_defense[away_team] * self.home_advantage
        lambda_away = self.team_attack[away_team] * self.team_defense[home_team]
        
        return {
            "home_team": home_team, 
            "away_team": away_team, 
            "home_goals": lambda_home, 
            "away_goals": lambda_away
        }
    
    def print_team_strengths(self, exclude_teams=None):
        """Print team strength analysis from the ensemble model."""
        if exclude_teams is None:
            exclude_teams = []

        # Check if parameters have been combined
        if not self.team_attack or not self.team_defense:
            self.combine_parameters()
            
        # Get all teams
        all_teams = set(self.team_attack.keys())
        all_teams = [team for team in all_teams if team not in exclude_teams]
        
        # Calculate the average attack and defense values across all teams
        total_attack = sum(self.team_attack.get(team, 0) for team in all_teams)
        total_defense = sum(self.team_defense.get(team, 0) for team in all_teams)
        num_teams = len(all_teams)
        
        avg_attack = total_attack / num_teams if num_teams > 0 else 1.0
        avg_defense = total_defense / num_teams if num_teams > 0 else 1.0
        
        print(f"Ensemble Model - League average attack: {avg_attack:.3f}")
        print(f"Ensemble Model - League average defense: {avg_defense:.3f}")
        
        # Create a list of team data
        team_data = []
        for team in all_teams:
            attack = self.team_attack.get(team, float('nan'))
            defense = self.team_defense.get(team, float('nan'))
            overall_log_strength = np.log(attack) - np.log(defense)
            overall_abs_strength = attack - defense
            
            # Calculate expected goals against average opponent (ignoring home/away)
            xg_vs_avg = attack * avg_defense  # Expected goals for vs average defense
            xga_vs_avg = avg_attack * defense  # Expected goals against vs average attack
            
            team_data.append({
                'team': team,
                'attack': attack,
                'defense': defense,
                'overall_log_strength': overall_log_strength,
                'overall_abs_strength': overall_abs_strength,
                'xg_vs_avg': xg_vs_avg,
                'xga_vs_avg': xga_vs_avg,
                'goal_diff_vs_avg': xg_vs_avg - xga_vs_avg
            })
        
        # Sort by overall strength (descending)
        team_data = sorted(team_data, key=lambda x: x['goal_diff_vs_avg'], reverse=True)
        
        # Print header
        print("\n{:<20} {:^20} {:^20} {:^30}".format('', 'Ensemble Model', 'Strength', 'Expected vs Average'))
        print("{:<20} {:^10} {:^10} {:^10} {:^10} {:^10} {:^10} {:^10}".format(
            'Team', 'Attack', 'Defence', 'Log', 'Abs', 'For', 'Against', 'Diff'))
        print("-" * 100)
        
        # Print team data
        for team in team_data:
            print("{:<20} {:^10.2f} {:^10.2f} {:^10.2f} {:^10.2f} {:^10.2f} {:^10.2f} {:^10.2f}".format(
                team['team'],
                team['attack'],
                team['defense'],
                team['overall_log_strength'],
                team['overall_abs_strength'],
                team['xg_vs_avg'],
                team['xga_vs_avg'],
                team['goal_diff_vs_avg']
            ))
        
        # Print model parameters
        print("\nEnsemble Model Parameters:")
        print(f"Home Advantage: {self.home_advantage:.3f}")
        print(f"Rho Parameter: {self.rho:.3f}")
        print("\nModel Weights:")
        for model_name, weight in sorted(self.weights.items()):
            if model_name in self.models:  # Only show weights for included models
                print(f"{model_name}: {weight:.3f}")
        
        return team_data
    
    @staticmethod
    def dc_probability(home_goals, away_goals, lambda_home, lambda_away, rho):
        """Calculate Dixon-Coles adjusted probability for a match outcome."""
        # Use the same probability calculation as StandardTeamModel
        from scipy.stats import poisson
        
        # Base Poisson probabilities
        p_home = poisson.pmf(home_goals, lambda_home)
        p_away = poisson.pmf(away_goals, lambda_away)
        
        # Dixon-Coles adjustment for low-scoring dependencies
        tau = 1.0
        if home_goals == 0 and away_goals == 0:
            tau = 1 - rho
        elif home_goals == 0 and away_goals == 1:
            tau = 1 + rho * lambda_home
        elif home_goals == 1 and away_goals == 0:
            tau = 1 + rho * lambda_away
        elif home_goals == 1 and away_goals == 1:
            tau = 1 - rho * lambda_home * lambda_away
        
        return tau * p_home * p_away

# %%
shot_data, match_stats = load_data()
matches = match_stats.to_dict('records')

StandardTeamModel = StandardTeamModel()
PSxGShotsTeamModel = PSxGShotsTeamModel(n_simulations=25)
PSxGTotalTeamModel = PSxGTotalTeamModel(n_simulations=25)
xGShotsTeamModel = xGShotsTeamModel(n_simulations=25)
xGTotalTeamModel = xGTotalTeamModel(n_simulations=25)

StandardTeamModel.fit_models(matches, epsilon=0.005, season_penalty=1, days_ago=365)
PSxGShotsTeamModel.fit_models(matches, shot_data, epsilon=0.005, season_penalty=1)
PSxGTotalTeamModel.fit_models(matches, epsilon=0.005, season_penalty=1)
xGShotsTeamModel.fit_models(matches, shot_data, epsilon=0.005, season_penalty=1)
xGTotalTeamModel.fit_models(matches, epsilon=0.005, season_penalty=1)
# Out:
# Optimizing for 907 matches with 47 teams
# Match 0: {'match_url': 'https://fbref.com/en/matches/008769e1/Norwich-City-Sheffield-United-August-24-2024-Championship', 'match_date': Timestamp('2024-08-24 00:00:00'), 'home_team': 'Norwich City', 'away_team': 'Sheffield Utd', 'season': 2024, 'division': 'EFL Championship', 'home_goals': 1, 'home_xg': 0.95, 'home_psxg': 1.53, 'away_goals': 1, 'away_xg': 0.8, 'away_psxg': 1.04, 'days_from_ref': 187}
# Match 1: {'match_url': 'https://fbref.com/en/matches/00bcfc31/Arsenal-Bournemouth-May-4-2024-Premier-League', 'match_date': Timestamp('2024-05-04 00:00:00'), 'home_team': 'Arsenal', 'away_team': 'Bournemouth', 'season': 2023, 'division': 'Premier League', 'home_goals': 3, 'home_xg': 3.39, 'home_psxg': 1.98, 'away_goals': 0, 'away_xg': 0.46, 'away_psxg': 0.33, 'days_from_ref': 299}
# Match 2: {'match_url': 'https://fbref.com/en/matches/00bde56f/Luton-Town-Swansea-City-December-7-2024-Championship', 'match_date': Timestamp('2024-12-07 00:00:00'), 'home_team': 'Luton Town', 'away_team': 'Swansea City', 'season': 2024, 'division': 'EFL Championship', 'home_goals': 1, 'home_xg': 1.1600000000000001, 'home_psxg': 1.22, 'away_goals': 1, 'away_xg': 2.25, 'away_psxg': 2.8200000000000003, 'days_from_ref': 82}
# Optimization success: True
# Final function value: 1263.6801601171924
# Number of iterations: 30
# Resimulating 907 matches (25 simulations each)
# Expanded from 907 to 23582 matches
# Optimizing for 23582 matches with 47 teams
# Match 0: {'match_url': 'https://fbref.com/en/matches/008769e1/Norwich-City-Sheffield-United-August-24-2024-Championship', 'match_date': Timestamp('2024-08-24 00:00:00'), 'home_team': 'Norwich City', 'away_team': 'Sheffield Utd', 'season': 2024, 'division': 'EFL Championship', 'home_goals': 1, 'home_xg': 0.95, 'home_psxg': 1.53, 'away_goals': 1, 'away_xg': 0.8, 'away_psxg': 1.04, 'days_from_ref': 187, 'weight': 1.0}
# Match 1: {'match_url': 'https://fbref.com/en/matches/00bcfc31/Arsenal-Bournemouth-May-4-2024-Premier-League', 'match_date': Timestamp('2024-05-04 00:00:00'), 'home_team': 'Arsenal', 'away_team': 'Bournemouth', 'season': 2023, 'division': 'Premier League', 'home_goals': 3, 'home_xg': 3.39, 'home_psxg': 1.98, 'away_goals': 0, 'away_xg': 0.46, 'away_psxg': 0.33, 'days_from_ref': 299, 'weight': 1.0}
# Match 2: {'match_url': 'https://fbref.com/en/matches/00bde56f/Luton-Town-Swansea-City-December-7-2024-Championship', 'match_date': Timestamp('2024-12-07 00:00:00'), 'home_team': 'Luton Town', 'away_team': 'Swansea City', 'season': 2024, 'division': 'EFL Championship', 'home_goals': 1, 'home_xg': 1.1600000000000001, 'home_psxg': 1.22, 'away_goals': 1, 'away_xg': 2.25, 'away_psxg': 2.8200000000000003, 'days_from_ref': 82, 'weight': 1.0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 11
#       8 xGTotalTeamModel = xGTotalTeamModel(n_simulations=25)
#      10 StandardTeamModel.fit_models(matches, epsilon=0.005, season_penalty=1, days_ago=365)
# ---> 11 PSxGShotsTeamModel.fit_models(matches, shot_data, epsilon=0.005, season_penalty=1)
#      12 PSxGTotalTeamModel.fit_models(matches, epsilon=0.005, season_penalty=1)
#      13 xGShotsTeamModel.fit_models(matches, shot_data, epsilon=0.005, season_penalty=1)
#
# File c:\Users\Owner\dev\team-model\models\psxg_shots_resimmed_dc.py:244, in PSxGShotsTeamModel.fit_models(self, actual_matches, shot_data, epsilon, season_penalty)
#     241 team_list = sorted(list(teams))
#     243 # Fit model with resimulated data and season penalty
# --> 244 params = self._optimize_dc_parameters(
#     245     resimulated_matches, team_list, matches_metadata, epsilon, season_penalty
#     246 )
#     248 # Extract parameters
#     249 self.home_advantage = params[0]
#
# File c:\Users\Owner\dev\team-model\models\psxg_shots_resimmed_dc.py:277, in PSxGShotsTeamModel._optimize_dc_parameters(self, matches, team_list, metadata, epsilon, season_penalty)
#     274 bounds.extend([(0.1, 3.0)] * len(team_list))  # Defense
#     276 # Minimize negative log-likelihood
# --> 277 result = minimize(
#     278     lambda params: PSxGShotsTeamModel.dc_log_likelihood(
#     279         params, matches, team_list, metadata,
#     280         epsilon=epsilon, season_penalty=season_penalty
#     281     ),
#     282     initial_params,
#     283     method='L-BFGS-B',
#     284     bounds=bounds
#     285 )
#     287 # Print optimization results
#     288 print(f"Optimization success: {result.success}")
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\optimize\_minimize.py:738, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     735     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     736                              **options)
#     737 elif meth == 'l-bfgs-b':
# --> 738     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     739                            callback=callback, **options)
#     740 elif meth == 'tnc':
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:441, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     433 _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr, pgtol, wa,
#     434                iwa, task, lsave, isave, dsave, maxls, ln_task)
#     436 if task[0] == 3:
#     437     # The minimization routine wants f and g at the current x.
#     438     # Note that interruptions due to maxfun are postponed
#     439     # until the completion of the current minimization iteration.
#     440     # Overwrite f and g:
# --> 441     f, g = func_and_grad(x)
#     442 elif task[0] == 1:
#     443     # new iteration
#     444     n_iterations += 1
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:345, in ScalarFunction.fun_and_grad(self, x)
#     343     self._update_x(x)
#     344 self._update_fun()
# --> 345 self._update_grad()
#     346 return self.f, self.g
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:307, in ScalarFunction._update_grad(self)
#     305 if self._orig_grad in FD_METHODS:
#     306     self._update_fun()
# --> 307 self.g = self._wrapped_grad(self.x, f0=self.f)
#     308 self.g_updated = True
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:48, in _wrapper_grad.<locals>.wrapped1(x, f0)
#      46 def wrapped1(x, f0=None):
#      47     ncalls[0] += 1
# ---> 48     return approx_derivative(
#      49         fun, x, f0=f0, **finite_diff_options
#      50     )
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\optimize\_numdiff.py:523, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     520     use_one_sided = False
#     522 if sparsity is None:
# --> 523     return _dense_difference(fun_wrapped, x0, f0, h,
#     524                              use_one_sided, method)
#     525 else:
#     526     if not issparse(sparsity) and len(sparsity) == 2:
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\optimize\_numdiff.py:596, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     594     x1[i] += h[i]
#     595     dx = x1[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 596     df = fun(x1) - f0
#     597 elif method == '3-point' and use_one_sided[i]:
#     598     x1[i] += h[i]
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\optimize\_numdiff.py:474, in approx_derivative.<locals>.fun_wrapped(x)
#     471 if xp.isdtype(x.dtype, "real floating"):
#     472     x = xp.astype(x, x0.dtype)
# --> 474 f = np.atleast_1d(fun(x, *args, **kwargs))
#     475 if f.ndim > 1:
#     476     raise RuntimeError("`fun` return value has "
#     477                        "more than 1 dimension.")
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File c:\Users\Owner\dev\team-model\models\psxg_shots_resimmed_dc.py:278, in PSxGShotsTeamModel._optimize_dc_parameters.<locals>.<lambda>(params)
#     274 bounds.extend([(0.1, 3.0)] * len(team_list))  # Defense
#     276 # Minimize negative log-likelihood
#     277 result = minimize(
# --> 278     lambda params: PSxGShotsTeamModel.dc_log_likelihood(
#     279         params, matches, team_list, metadata,
#     280         epsilon=epsilon, season_penalty=season_penalty
#     281     ),
#     282     initial_params,
#     283     method='L-BFGS-B',
#     284     bounds=bounds
#     285 )
#     287 # Print optimization results
#     288 print(f"Optimization success: {result.success}")
#
# File c:\Users\Owner\dev\team-model\models\psxg_shots_resimmed_dc.py:165, in PSxGShotsTeamModel.dc_log_likelihood(params, matches, teams, metadata, epsilon, season_penalty)
#     162 lambda_away = attack[away_team] * defense[home_team]
#     164 # Calculate probability with rho adjustment
# --> 165 probability = PSxGShotsTeamModel.dc_probability(home_goals, away_goals, lambda_home, lambda_away, rho)
#     167 # Safeguard against log(0)
#     168 if probability <= 0:
#
# File c:\Users\Owner\dev\team-model\models\psxg_shots_resimmed_dc.py:90, in PSxGShotsTeamModel.dc_probability(home_goals, away_goals, lambda_home, lambda_away, rho)
#      88 """Calculate Dixon-Coles adjusted probability for a match outcome."""
#      89 # Base Poisson probabilities
# ---> 90 p_home = poisson.pmf(home_goals, lambda_home)
#      91 p_away = poisson.pmf(away_goals, lambda_away)
#      93 # Dixon-Coles adjustment for low-scoring dependencies
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\scipy\stats\_distn_infrastructure.py:3498, in rv_discrete.pmf(self, k, *args, **kwds)
#    3496 if np.any(cond):
#    3497     goodargs = argsreduce(cond, *((k,)+args))
# -> 3498     place(output, cond, np.clip(self._pmf(*goodargs), 0, 1))
#    3499 if output.ndim == 0:
#    3500     return output[()]
#
# File c:\Users\Owner\dev\team-model\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:2085, in place(arr, mask, vals)
#    2047 @array_function_dispatch(_place_dispatcher)
#    2048 def place(arr, mask, vals):
#    2049     """
#    2050     Change elements of an array based on conditional and input values.
#    2051
#    (...)
#    2083
#    2084     """
# -> 2085     return _place(arr, mask, vals)
#
# KeyboardInterrupt:

# %%
model_weights = {
    'standard': 0.3,       
    'psxg_shots': 0.175,    
    'psxg_total': 0.175,     
    'xg_shots': 0.175,       
    'xg_total': 0.175        
}

# Initialize the ensemble model
ensemble = EnsembleTeamModel(model_weights=model_weights)

# Add each model to the ensemble
ensemble.add_model('standard', StandardTeamModel)
ensemble.add_model('psxg_shots', PSxGShotsTeamModel)
ensemble.add_model('psxg_total', PSxGTotalTeamModel)
ensemble.add_model('xg_shots', xGShotsTeamModel)
ensemble.add_model('xg_total', xGTotalTeamModel)

# Combine the parameters from all models
ensemble.combine_parameters()

# %%
prediction = ensemble.predict_match('Liverpool', 'Southampton')
print(prediction)

# To print team strengths:
ensemble.print_team_strengths()
# Out:
# {'home_team': 'Liverpool', 'away_team': 'Southampton', 'home_goals': np.float64(3.767356551530681), 'away_goals': np.float64(0.42059318897778314)}
# Ensemble Model - League average attack: 1.070
# Ensemble Model - League average defense: 1.070
#
#                         Ensemble Model          Strength            Expected vs Average
# Team                   Attack    Defence      Log        Abs        For      Against      Diff
# ----------------------------------------------------------------------------------------------------
# Liverpool               1.69       0.74       0.82       0.94       1.81       0.80       1.01
# Arsenal                 1.30       0.56       0.83       0.73       1.39       0.60       0.79
# Manchester City         1.59       0.89       0.59       0.71       1.71       0.95       0.76
# Chelsea                 1.56       1.04       0.40       0.52       1.67       1.11       0.56
# Newcastle Utd           1.36       1.02       0.29       0.34       1.45       1.09       0.37
# Crystal Palace          1.13       0.85       0.29       0.28       1.21       0.90       0.30
# Bournemouth             1.28       1.01       0.24       0.27       1.36       1.08       0.29
# Nott'ham Forest         1.16       0.93       0.22       0.23       1.24       0.99       0.24
# Brentford               1.27       1.08       0.17       0.19       1.36       1.15       0.21
# Fulham                  1.10       0.92       0.18       0.18       1.18       0.99       0.19
# Tottenham               1.30       1.13       0.14       0.17       1.39       1.21       0.18
# Brighton                1.11       1.00       0.11       0.11       1.19       1.07       0.12
# Everton                 0.83       0.88      -0.06      -0.05       0.89       0.95      -0.05
# Aston Villa             1.07       1.16      -0.08      -0.09       1.14       1.24      -0.10
# Manchester Utd          0.97       1.08      -0.11      -0.11       1.03       1.16      -0.12
# West Ham                0.96       1.14      -0.18      -0.18       1.03       1.22      -0.20
# Burnley                 0.74       0.98      -0.28      -0.24       0.79       1.05      -0.26
# Wolves                  0.92       1.21      -0.27      -0.29       0.98       1.29      -0.31
# Luton Town              0.69       1.16      -0.51      -0.47       0.74       1.24      -0.50
# Sheffield Utd           0.65       1.27      -0.67      -0.62       0.69       1.36      -0.66
# Ipswich Town            0.72       1.44      -0.70      -0.73       0.77       1.54      -0.78
# Leicester City          0.67       1.46      -0.79      -0.80       0.71       1.57      -0.85
# Southampton             0.56       1.67      -1.08      -1.10       0.60       1.78      -1.18
#
# Ensemble Model Parameters:
# Home Advantage: 1.337
# Rho Parameter: -0.096
#
# Model Weights:
# psxg_shots: 0.175
# psxg_total: 0.175
# standard: 0.300
# xg_shots: 0.175
# xg_total: 0.175
# [{'team': 'Liverpool',
#   'attack': np.float64(1.689567902689479),
#   'defense': np.float64(0.744943501008089),
#   'overall_log_strength': np.float64(0.8189197184130257),
#   'overall_abs_strength': np.float64(0.94462440168139),
#   'xg_vs_avg': np.float64(1.8080626755061417),
#   'xga_vs_avg': np.float64(0.7971813546916113),
#   'goal_diff_vs_avg': np.float64(1.0108813208145304)},
#  {'team': 'Arsenal',
#   'attack': np.float64(1.2982529794312958),
#   'defense': np.float64(0.5633011044055569),
#   'overall_log_strength': np.float64(0.8349604711833959),
#   'overall_abs_strength': np.float64(0.7349518750257389),
#   'xg_vs_avg': np.float64(1.3893035916093492),
#   'xga_vs_avg': np.float64(0.6028016042849222),
#   'goal_diff_vs_avg': np.float64(0.786501987324427)},
#  {'team': 'Manchester City',
#   'attack': np.float64(1.5939468169405466),
#   'defense': np.float64(0.885186683071205),
#   'overall_log_strength': np.float64(0.5881699301780773),
#   'overall_abs_strength': np.float64(0.7087601338693417),
#   'xg_vs_avg': np.float64(1.7057353787702072),
#   'xga_vs_avg': np.float64(0.9472588434032325),
#   'goal_diff_vs_avg': np.float64(0.7584765353669747)},
#  {'team': 'Chelsea',
#   'attack': np.float64(1.561143811372772),
#   'defense': np.float64(1.0413002518868293),
#   'overall_log_strength': np.float64(0.40494859056079596),
#   'overall_abs_strength': np.float64(0.5198435594859427),
#   'xg_vs_avg': np.float64(1.6706317940506448),
#   'xga_vs_avg': np.float64(1.1143196018443349),
#   'goal_diff_vs_avg': np.float64(0.5563121922063099)},
#  {'team': 'Newcastle Utd',
#   'attack': np.float64(1.3570508780437058),
#   'defense': np.float64(1.0153640642494912),
#   'overall_log_strength': np.float64(0.2900666410096838),
#   'overall_abs_strength': np.float64(0.3416868137942146),
#   'xg_vs_avg': np.float64(1.452225173932301),
#   'xga_vs_avg': np.float64(1.0865646846347887),
#   'goal_diff_vs_avg': np.float64(0.3656604892975124)},
#  {'team': 'Crystal Palace',
#   'attack': np.float64(1.1304251493436346),
#   'defense': np.float64(0.8456763140021697),
#   'overall_log_strength': np.float64(0.29021240047285457),
#   'overall_abs_strength': np.float64(0.2847488353414649),
#   'xg_vs_avg': np.float64(1.2097054618096168),
#   'xga_vs_avg': np.float64(0.9049778791472908),
#   'goal_diff_vs_avg': np.float64(0.304727582662326)},
#  {'team': 'Bournemouth',
#   'attack': np.float64(1.2753360212378861),
#   'defense': np.float64(1.007633286150205),
#   'overall_log_strength': np.float64(0.23560538992291333),
#   'overall_abs_strength': np.float64(0.26770273508768105),
#   'xg_vs_avg': np.float64(1.364779394221555),
#   'xga_vs_avg': np.float64(1.07829179930903),
#   'goal_diff_vs_avg': np.float64(0.28648759491252496)},
#  {'team': "Nott'ham Forest",
#   'attack': np.float64(1.1550155482580458),
#   'defense': np.float64(0.9270660812579796),
#   'overall_log_strength': np.float64(0.21984423646742918),
#   'overall_abs_strength': np.float64(0.22794946700006613),
#   'xg_vs_avg': np.float64(1.2360204636406649),
#   'xga_vs_avg': np.float64(0.9920749607799514),
#   'goal_diff_vs_avg': np.float64(0.24394550286071348)},
#  {'team': 'Brentford',
#   'attack': np.float64(1.2728472080835727),
#   'defense': np.float64(1.0786530918138324),
#   'overall_log_strength': np.float64(0.16554316169594357),
#   'overall_abs_strength': np.float64(0.19419411626974026),
#   'xg_vs_avg': np.float64(1.362116032681921),
#   'xga_vs_avg': np.float64(1.1542917440192673),
#   'goal_diff_vs_avg': np.float64(0.2078242886626538)},
#  {'team': 'Fulham',
#   'attack': np.float64(1.1030933082338732),
#   'defense': np.float64(0.9211001843729226),
#   'overall_log_strength': np.float64(0.18030480246900707),
#   'overall_abs_strength': np.float64(0.18199312386095057),
#   'xg_vs_avg': np.float64(1.180456751719445),
#   'xga_vs_avg': np.float64(0.9856907158615861),
#   'goal_diff_vs_avg': np.float64(0.194766035857859)},
#  {'team': 'Tottenham',
#   'attack': np.float64(1.2950862249347528),
#   'defense': np.float64(1.1263427033631102),
#   'overall_log_strength': np.float64(0.13960143781097753),
#   'overall_abs_strength': np.float64(0.16874352157164263),
#   'xg_vs_avg': np.float64(1.385914742544108),
#   'xga_vs_avg': np.float64(1.2053255057584105),
#   'goal_diff_vs_avg': np.float64(0.1805892367856976)},
#  {'team': 'Brighton',
#   'attack': np.float64(1.1078317318513444),
#   'defense': np.float64(0.9963469008812166),
#   'overall_log_strength': np.float64(0.10606449821242755),
#   'overall_abs_strength': np.float64(0.11148483097012785),
#   'xg_vs_avg': np.float64(1.1855274960617403),
#   'xga_vs_avg': np.float64(1.0662139761101859),
#   'goal_diff_vs_avg': np.float64(0.11931351995155448)},
#  {'team': 'Everton',
#   'attack': np.float64(0.833013906550155),
#   'defense': np.float64(0.883259697236988),
#   'overall_log_strength': np.float64(-0.05856892865338971),
#   'overall_abs_strength': np.float64(-0.0502457906868331),
#   'xg_vs_avg': np.float64(0.8914358222675741),
#   'xga_vs_avg': np.float64(0.9451967310742924),
#   'goal_diff_vs_avg': np.float64(-0.053760908806718244)},
#  {'team': 'Aston Villa',
#   'attack': np.float64(1.0689030800174892),
#   'defense': np.float64(1.1628113670571174),
#   'overall_log_strength': np.float64(-0.0842077014688172),
#   'overall_abs_strength': np.float64(-0.09390828703962817),
#   'xg_vs_avg': np.float64(1.1438686540131155),
#   'xga_vs_avg': np.float64(1.2443514703960505),
#   'goal_diff_vs_avg': np.float64(-0.10048281638293499)},
#  {'team': 'Manchester Utd',
#   'attack': np.float64(0.9659838385621855),
#   'defense': np.float64(1.080636188053872),
#   'overall_log_strength': np.float64(-0.11215810589592036),
#   'overall_abs_strength': np.float64(-0.11465234949168646),
#   'xg_vs_avg': np.float64(1.0337313586901355),
#   'xga_vs_avg': np.float64(1.1564139013976178),
#   'goal_diff_vs_avg': np.float64(-0.12268254270748224)},
#  {'team': 'West Ham',
#   'attack': np.float64(0.9593754862129111),
#   'defense': np.float64(1.14414534652699),
#   'overall_log_strength': np.float64(-0.1761306774522194),
#   'overall_abs_strength': np.float64(-0.18476986031407883),
#   'xg_vs_avg': np.float64(1.0266595415644097),
#   'xga_vs_avg': np.float64(1.2243765279839456),
#   'goal_diff_vs_avg': np.float64(-0.19771698641953583)},
#  {'team': 'Burnley',
#   'attack': np.float64(0.7411998500739441),
#   'defense': np.float64(0.9828307849197135),
#   'overall_log_strength': np.float64(-0.2821666717071607),
#   'overall_abs_strength': np.float64(-0.24163093484576947),
#   'xg_vs_avg': np.float64(0.7931825538803138),
#   'xga_vs_avg': np.float64(1.051750066273025),
#   'goal_diff_vs_avg': np.float64(-0.25856751239271125)},
#  {'team': 'Wolves',
#   'attack': np.float64(0.9169373206733696),
#   'defense': np.float64(1.2054498953592678),
#   'overall_log_strength': np.float64(-0.27356901606036577),
#   'overall_abs_strength': np.float64(-0.2885125746858982),
#   'xg_vs_avg': np.float64(0.9812450524474854),
#   'xga_vs_avg': np.float64(1.2899799505532266),
#   'goal_diff_vs_avg': np.float64(-0.3087348981057412)},
#  {'team': 'Luton Town',
#   'attack': np.float64(0.6936004626071135),
#   'defense': np.float64(1.1588286074850063),
#   'overall_log_strength': np.float64(-0.5132688603225398),
#   'overall_abs_strength': np.float64(-0.46522814487789277),
#   'xg_vs_avg': np.float64(0.7422448699205656),
#   'xga_vs_avg': np.float64(1.2400894268091074),
#   'goal_diff_vs_avg': np.float64(-0.4978445568885418)},
#  {'team': 'Sheffield Utd',
#   'attack': np.float64(0.6480003764650712),
#   'defense': np.float64(1.2683745753943745),
#   'overall_log_strength': np.float64(-0.6716002205189916),
#   'overall_abs_strength': np.float64(-0.6203741989293032),
#   'xg_vs_avg': np.float64(0.693446704648812),
#   'xga_vs_avg': np.float64(1.3573171131783661),
#   'goal_diff_vs_avg': np.float64(-0.6638704085295541)},
#  {'team': 'Ipswich Town',
#   'attack': np.float64(0.715861257176857),
#   'defense': np.float64(1.4421223337583964),
#   'overall_log_strength': np.float64(-0.7003847771261735),
#   'overall_abs_strength': np.float64(-0.7262610765815394),
#   'xg_vs_avg': np.float64(0.7660668848420105),
#   'xga_vs_avg': np.float64(1.5432486277158126),
#   'goal_diff_vs_avg': np.float64(-0.7771817428738022)},
#  {'team': 'Leicester City',
#   'attack': np.float64(0.665763982293664),
#   'defense': np.float64(1.4642998393995021),
#   'overall_log_strength': np.float64(-0.7881972550917067),
#   'overall_abs_strength': np.float64(-0.7985358571058382),
#   'xg_vs_avg': np.float64(0.7124561286737099),
#   'xga_vs_avg': np.float64(1.5669812919604607),
#   'goal_diff_vs_avg': np.float64(-0.8545251632867508)},
#  {'team': 'Southampton',
#   'attack': np.float64(0.5645974337766806),
#   'defense': np.float64(1.6673903788463114),
#   'overall_log_strength': np.float64(-1.0829020652034813),
#   'overall_abs_strength': np.float64(-1.1027929450696308),
#   'xg_vs_avg': np.float64(0.6041944482214645),
#   'xga_vs_avg': np.float64(1.7843131985307812),
#   'goal_diff_vs_avg': np.float64(-1.1801187503093167)}]

# %%
shot_data, match_stats = load_data()
matches = match_stats.to_dict('records')

teammodel = StandardTeamModel()

teammodel.fit_models(matches, epsilon=0.005, season_penalty=1, days_ago=365)
# Out:
# Optimizing for 936 matches with 47 teams
# Match 0: {'match_url': 'https://fbref.com/en/matches/008769e1/Norwich-City-Sheffield-United-August-24-2024-Championship', 'match_date': Timestamp('2024-08-24 00:00:00'), 'home_team': 'Norwich City', 'away_team': 'Sheffield Utd', 'season': 2024, 'home_goals': 1, 'home_xg': 0.95, 'home_psxg': 1.53, 'away_goals': 1, 'away_xg': 0.8, 'away_psxg': 1.04, 'days_from_ref': 187}
# Match 1: {'match_url': 'https://fbref.com/en/matches/00bcfc31/Arsenal-Bournemouth-May-4-2024-Premier-League', 'match_date': Timestamp('2024-05-04 00:00:00'), 'home_team': 'Arsenal', 'away_team': 'Bournemouth', 'season': 2023, 'home_goals': 3, 'home_xg': 3.39, 'home_psxg': 1.98, 'away_goals': 0, 'away_xg': 0.46, 'away_psxg': 0.33, 'days_from_ref': 299}
# Match 2: {'match_url': 'https://fbref.com/en/matches/00bde56f/Luton-Town-Swansea-City-December-7-2024-Championship', 'match_date': Timestamp('2024-12-07 00:00:00'), 'home_team': 'Luton Town', 'away_team': 'Swansea City', 'season': 2024, 'home_goals': 1, 'home_xg': 1.1600000000000001, 'home_psxg': 1.22, 'away_goals': 1, 'away_xg': 2.25, 'away_psxg': 2.8200000000000003, 'days_from_ref': 82}
# Optimization success: True
# Final function value: 1597.938859621471
# Number of iterations: 27

# %%
teammodel.print_team_strengths()
# Out:
# League average attack: 1.019
# League average defense: 1.019
#
#                         Standard Model          Strength            Expected vs Average
# Team                   Attack    Defence      Log        Abs        For      Against      Diff
# ----------------------------------------------------------------------------------------------------
# Liverpool               1.97       0.60       1.18       1.37       2.01       0.62       1.40
# Manchester City         1.90       0.70       1.00       1.20       1.94       0.71       1.22
# Arsenal                 1.57       0.46       1.23       1.11       1.60       0.47       1.14
# Chelsea                 1.80       0.88       0.72       0.92       1.83       0.89       0.94
# Newcastle Utd           1.67       0.86       0.67       0.81       1.70       0.87       0.83
# Leeds United            1.34       0.63       0.76       0.71       1.37       0.64       0.73
# Tottenham               1.55       0.86       0.59       0.69       1.58       0.88       0.71
# Bournemouth             1.43       0.76       0.63       0.66       1.46       0.78       0.68
# Nott'ham Forest         1.44       0.77       0.62       0.66       1.46       0.79       0.67
# Brentford               1.50       0.89       0.52       0.61       1.53       0.91       0.62
# Crystal Palace          1.26       0.66       0.64       0.60       1.28       0.67       0.61
# Fulham                  1.25       0.80       0.45       0.45       1.28       0.82       0.46
# Burnley                 0.80       0.39       0.72       0.41       0.82       0.40       0.42
# Brighton                1.23       0.85       0.37       0.38       1.26       0.87       0.39
# Manchester Utd          1.15       0.91       0.24       0.25       1.18       0.92       0.25
# Aston Villa             1.25       1.02       0.20       0.23       1.28       1.04       0.23
# Everton                 0.93       0.73       0.24       0.20       0.95       0.74       0.20
# West Ham                1.08       0.97       0.10       0.10       1.10       0.99       0.10
# Sunderland              0.88       0.79       0.11       0.09       0.90       0.81       0.09
# Wolves                  1.14       1.07       0.06       0.07       1.16       1.09       0.07
# Sheffield Utd           0.94       0.88       0.07       0.07       0.96       0.89       0.07
# West Brom               0.92       0.96      -0.04      -0.04       0.94       0.98      -0.04
# Middlesbrough           1.10       1.16      -0.05      -0.06       1.13       1.18      -0.06
# Blackburn               0.77       0.85      -0.09      -0.08       0.79       0.87      -0.08
# Coventry City           0.96       1.05      -0.09      -0.09       0.98       1.07      -0.09
# Norwich City            1.04       1.18      -0.13      -0.14       1.06       1.20      -0.14
# Millwall                0.65       0.83      -0.25      -0.19       0.66       0.85      -0.19
# Bristol City            0.83       1.03      -0.22      -0.20       0.85       1.05      -0.21
# QPR                     0.80       1.08      -0.30      -0.28       0.81       1.10      -0.28
# Ipswich Town            0.93       1.21      -0.27      -0.28       0.95       1.24      -0.29
# Stoke City              0.73       1.02      -0.33      -0.28       0.75       1.04      -0.29
# Preston                 0.71       1.04      -0.38      -0.33       0.73       1.06      -0.34
# Watford                 0.86       1.23      -0.37      -0.38       0.87       1.26      -0.39
# Birmingham City         0.44       0.83      -0.63      -0.39       0.45       0.84      -0.40
# Sheffield Weds          0.96       1.36      -0.35      -0.40       0.97       1.38      -0.41
# Leicester City          0.86       1.26      -0.39      -0.41       0.87       1.29      -0.42
# Hull City               0.74       1.23      -0.50      -0.49       0.76       1.25      -0.49
# Portsmouth              0.89       1.40      -0.45      -0.51       0.91       1.42      -0.52
# Swansea City            0.70       1.22      -0.56      -0.53       0.71       1.25      -0.54
# Oxford United           0.70       1.30      -0.62      -0.60       0.71       1.33      -0.62
# Southampton             0.78       1.39      -0.58      -0.61       0.79       1.42      -0.62
# Derby County            0.58       1.26      -0.78      -0.68       0.59       1.29      -0.70
# Luton Town              0.71       1.46      -0.72      -0.75       0.73       1.49      -0.76
# Cardiff City            0.77       1.57      -0.71      -0.80       0.79       1.60      -0.82
# Huddersfield            0.41       1.39      -1.23      -0.98       0.42       1.42      -1.00
# Rotherham Utd           0.32       1.35      -1.44      -1.03       0.33       1.38      -1.05
# Plymouth Argyle         0.68       1.74      -0.95      -1.07       0.69       1.78      -1.09
#
# Model Parameters:
# Home Advantage: Standard=1.423
# Rho Parameter: Standard=-0.119
# [{'team': 'Liverpool',
#   'std_attack': np.float64(1.9727911197388128),
#   'std_defense': np.float64(0.6039511278727037),
#   'overall_log_strength': np.float64(1.1837113505079588),
#   'overall_abs_strength': np.float64(1.3688399918661092),
#   'xg_vs_avg': np.float64(2.011257280964788),
#   'xga_vs_avg': np.float64(0.6157228436306403),
#   'goal_diff_vs_avg': np.float64(1.3955344373341476)},
#  {'team': 'Manchester City',
#   'std_attack': np.float64(1.9009300680165904),
#   'std_defense': np.float64(0.6995216582498206),
#   'overall_log_strength': np.float64(0.9997017987671184),
#   'overall_abs_strength': np.float64(1.2014084097667697),
#   'xg_vs_avg': np.float64(1.937995057687322),
#   'xga_vs_avg': np.float64(0.7131561557238828),
#   'goal_diff_vs_avg': np.float64(1.2248389019634391)},
#  {'team': 'Arsenal',
#   'std_attack': np.float64(1.5730469812967214),
#   'std_defense': np.float64(0.45908261908949993),
#   'overall_log_strength': np.float64(1.2315395780545737),
#   'overall_abs_strength': np.float64(1.1139643622072215),
#   'xg_vs_avg': np.float64(1.603718793529232),
#   'xga_vs_avg': np.float64(0.4680306777186243),
#   'goal_diff_vs_avg': np.float64(1.1356881158106078)},
#  {'team': 'Chelsea',
#   'std_attack': np.float64(1.797707569142107),
#   'std_defense': np.float64(0.8763123331481826),
#   'overall_log_strength': np.float64(0.7185449874233415),
#   'overall_abs_strength': np.float64(0.9213952359939244),
#   'xg_vs_avg': np.float64(1.832759890951489),
#   'xga_vs_avg': np.float64(0.8933926882049398),
#   'goal_diff_vs_avg': np.float64(0.9393672027465493)},
#  {'team': 'Newcastle Utd',
#   'std_attack': np.float64(1.6684526767452152),
#   'std_defense': np.float64(0.857989431323865),
#   'overall_log_strength': np.float64(0.6650601534276123),
#   'overall_abs_strength': np.float64(0.8104632454213503),
#   'xg_vs_avg': np.float64(1.7009847421116127),
#   'xga_vs_avg': np.float64(0.8747126515361254),
#   'goal_diff_vs_avg': np.float64(0.8262720905754872)},
#  {'team': 'Leeds United',
#   'std_attack': np.float64(1.3411569197320143),
#   'std_defense': np.float64(0.6288200504257518),
#   'overall_log_strength': np.float64(0.7574427659712435),
#   'overall_abs_strength': np.float64(0.7123368693062625),
#   'xg_vs_avg': np.float64(1.3673072596172495),
#   'xga_vs_avg': np.float64(0.6410764906489475),
#   'goal_diff_vs_avg': np.float64(0.7262307689683021)},
#  {'team': 'Tottenham',
#   'std_attack': np.float64(1.5530722574486184),
#   'std_defense': np.float64(0.8592129737734959),
#   'overall_log_strength': np.float64(0.5919735262514823),
#   'overall_abs_strength': np.float64(0.6938592836751225),
#   'xg_vs_avg': np.float64(1.5833545956307353),
#   'xga_vs_avg': np.float64(0.875960042262993),
#   'goal_diff_vs_avg': np.float64(0.7073945533677424)},
#  {'team': 'Bournemouth',
#   'std_attack': np.float64(1.4281507357803542),
#   'std_defense': np.float64(0.7633562316658851),
#   'overall_log_strength': np.float64(0.6264108893520888),
#   'overall_abs_strength': np.float64(0.6647945041144692),
#   'xg_vs_avg': np.float64(1.455997311075561),
#   'xga_vs_avg': np.float64(0.7782349398369781),
#   'goal_diff_vs_avg': np.float64(0.677762371238583)},
#  {'team': "Nott'ham Forest",
#   'std_attack': np.float64(1.4360435936125473),
#   'std_defense': np.float64(0.7745221084221008),
#   'overall_log_strength': np.float64(0.6174009019541244),
#   'overall_abs_strength': np.float64(0.6615214851904465),
#   'xg_vs_avg': np.float64(1.464044066570243),
#   'xga_vs_avg': np.float64(0.7896184526258068),
#   'goal_diff_vs_avg': np.float64(0.6744256139444362)},
#  {'team': 'Brentford',
#   'std_attack': np.float64(1.5000027845501451),
#   'std_defense': np.float64(0.8904874100115299),
#   'overall_log_strength': np.float64(0.5214532789372709),
#   'overall_abs_strength': np.float64(0.6095153745386153),
#   'xg_vs_avg': np.float64(1.5292503558579258),
#   'xga_vs_avg': np.float64(0.9078440539399876),
#   'goal_diff_vs_avg': np.float64(0.6214063019179382)},
#  {'team': 'Crystal Palace',
#   'std_attack': np.float64(1.2589087727038755),
#   'std_defense': np.float64(0.6619263418296324),
#   'overall_log_strength': np.float64(0.6428462876668843),
#   'overall_abs_strength': np.float64(0.5969824308742431),
#   'xg_vs_avg': np.float64(1.2834554098694122),
#   'xga_vs_avg': np.float64(0.674828062497255),
#   'goal_diff_vs_avg': np.float64(0.6086273473721572)},
#  {'team': 'Fulham',
#   'std_attack': np.float64(1.2535381531625869),
#   'std_defense': np.float64(0.8009534191725846),
#   'overall_log_strength': np.float64(0.4479225624059595),
#   'overall_abs_strength': np.float64(0.4525847339900023),
#   'xg_vs_avg': np.float64(1.2779800721371852),
#   'xga_vs_avg': np.float64(0.8165649406197876),
#   'goal_diff_vs_avg': np.float64(0.46141513151739766)},
#  {'team': 'Burnley',
#   'std_attack': np.float64(0.8047822840703456),
#   'std_defense': np.float64(0.39148100934244723),
#   'overall_log_strength': np.float64(0.7206347794404959),
#   'overall_abs_strength': np.float64(0.41330127472789835),
#   'xg_vs_avg': np.float64(0.8204742064341065),
#   'xga_vs_avg': np.float64(0.39911143331870774),
#   'goal_diff_vs_avg': np.float64(0.42136277311539877)},
#  {'team': 'Brighton',
#   'std_attack': np.float64(1.2319509888513684),
#   'std_defense': np.float64(0.8540273058149379),
#   'overall_log_strength': np.float64(0.36639119422607536),
#   'overall_abs_strength': np.float64(0.37792368303643054),
#   'xg_vs_avg': np.float64(1.2559719938556542),
#   'xga_vs_avg': np.float64(0.8706732995544991),
#   'goal_diff_vs_avg': np.float64(0.38529869430115504)},
#  {'team': 'Manchester Utd',
#   'std_attack': np.float64(1.153306698168993),
#   'std_defense': np.float64(0.9071440421527356),
#   'overall_log_strength': np.float64(0.24008723590318753),
#   'overall_abs_strength': np.float64(0.24616265601625742),
#   'xg_vs_avg': np.float64(1.1757942696867718),
#   'xga_vs_avg': np.float64(0.9248253433754705),
#   'goal_diff_vs_avg': np.float64(0.2509689263113013)},
#  {'team': 'Aston Villa',
#   'std_attack': np.float64(1.251365273914999),
#   'std_defense': np.float64(1.0244033040982943),
#   'overall_log_strength': np.float64(0.20012487367225484),
#   'overall_abs_strength': np.float64(0.2269619698167047),
#   'xg_vs_avg': np.float64(1.275764825341089),
#   'xga_vs_avg': np.float64(1.0443701258505969),
#   'goal_diff_vs_avg': np.float64(0.23139469949049207)},
#  {'team': 'Everton',
#   'std_attack': np.float64(0.9286818517709767),
#   'std_defense': np.float64(0.7294876753353889),
#   'overall_log_strength': np.float64(0.24142374390391325),
#   'overall_abs_strength': np.float64(0.1991941764355878),
#   'xg_vs_avg': np.float64(0.946789610610944),
#   'xga_vs_avg': np.float64(0.7437062456246991),
#   'goal_diff_vs_avg': np.float64(0.2030833649862449)},
#  {'team': 'West Ham',
#   'std_attack': np.float64(1.0762674950161237),
#   'std_defense': np.float64(0.9743224827848089),
#   'overall_log_strength': np.float64(0.09951197114285458),
#   'overall_abs_strength': np.float64(0.1019450122313148),
#   'xg_vs_avg': np.float64(1.0972529295972808),
#   'xga_vs_avg': np.float64(0.9933131705980908),
#   'goal_diff_vs_avg': np.float64(0.10393975899919006)},
#  {'team': 'Sunderland',
#   'std_attack': np.float64(0.8801633780044171),
#   'std_defense': np.float64(0.7916008788785471),
#   'overall_log_strength': np.float64(0.10605022307969336),
#   'overall_abs_strength': np.float64(0.08856249912587),
#   'xg_vs_avg': np.float64(0.8973251069197415),
#   'xga_vs_avg': np.float64(0.8070301083473514),
#   'goal_diff_vs_avg': np.float64(0.0902949985723901)},
#  {'team': 'Wolves',
#   'std_attack': np.float64(1.1382962898388036),
#   'std_defense': np.float64(1.0692112426117582),
#   'overall_log_strength': np.float64(0.06261144175306468),
#   'overall_abs_strength': np.float64(0.06908504722704545),
#   'xg_vs_avg': np.float64(1.1604911832412363),
#   'xga_vs_avg': np.float64(1.0900514236336054),
#   'goal_diff_vs_avg': np.float64(0.07043975960763094)},
#  {'team': 'Sheffield Utd',
#   'std_attack': np.float64(0.9444143786829732),
#   'std_defense': np.float64(0.8773839641721516),
#   'overall_log_strength': np.float64(0.07362031826517998),
#   'overall_abs_strength': np.float64(0.06703041451082159),
#   'xg_vs_avg': np.float64(0.9628288957552915),
#   'xga_vs_avg': np.float64(0.8944852065743071),
#   'goal_diff_vs_avg': np.float64(0.06834368918098443)},
#  {'team': 'West Brom',
#   'std_attack': np.float64(0.9209549230643338),
#   'std_defense': np.float64(0.9590415382955445),
#   'overall_log_strength': np.float64(-0.04052329653444194),
#   'overall_abs_strength': np.float64(-0.03808661523121071),
#   'xg_vs_avg': np.float64(0.9389120195850938),
#   'xga_vs_avg': np.float64(0.977734382580205),
#   'goal_diff_vs_avg': np.float64(-0.038822362995111104)},
#  {'team': 'Middlesbrough',
#   'std_attack': np.float64(1.1037556897185177),
#   'std_defense': np.float64(1.161039982061441),
#   'overall_log_strength': np.float64(-0.050597511908936785),
#   'overall_abs_strength': np.float64(-0.057284292342923315),
#   'xg_vs_avg': np.float64(1.1252770985944969),
#   'xga_vs_avg': np.float64(1.1836700129061022),
#   'goal_diff_vs_avg': np.float64(-0.058392914311605315)},
#  {'team': 'Blackburn',
#   'std_attack': np.float64(0.7747530194229072),
#   'std_defense': np.float64(0.8515907663295375),
#   'overall_log_strength': np.float64(-0.094561796281659),
#   'overall_abs_strength': np.float64(-0.07683774690663026),
#   'xg_vs_avg': np.float64(0.7898594208342123),
#   'xga_vs_avg': np.float64(0.8681892690571087),
#   'goal_diff_vs_avg': np.float64(-0.07832984822289635)},
#  {'team': 'Coventry City',
#   'std_attack': np.float64(0.9598575171894234),
#   'std_defense': np.float64(1.0524409990887769),
#   'overall_log_strength': np.float64(-0.09208265226008579),
#   'overall_abs_strength': np.float64(-0.0925834818993535),
#   'xg_vs_avg': np.float64(0.9785731498992162),
#   'xga_vs_avg': np.float64(1.07295430839728),
#   'goal_diff_vs_avg': np.float64(-0.09438115849806372)},
#  {'team': 'Norwich City',
#   'std_attack': np.float64(1.0363560927234412),
#   'std_defense': np.float64(1.1762317597840752),
#   'overall_log_strength': np.float64(-0.1266051010815785),
#   'overall_abs_strength': np.float64(-0.13987566706063403),
#   'xg_vs_avg': np.float64(1.0565633210262022),
#   'xga_vs_avg': np.float64(1.199157896192507),
#   'goal_diff_vs_avg': np.float64(-0.1425945751663047)},
#  {'team': 'Millwall',
#   'std_attack': np.float64(0.6456931098345197),
#   'std_defense': np.float64(0.8326580815665535),
#   'overall_log_strength': np.float64(-0.25429876286668096),
#   'overall_abs_strength': np.float64(-0.18696497173203386),
#   'xg_vs_avg': np.float64(0.6582830566448461),
#   'xga_vs_avg': np.float64(0.8488875640650385),
#   'goal_diff_vs_avg': np.float64(-0.19060450742019241)},
#  {'team': 'Bristol City',
#   'std_attack': np.float64(0.8304387770849058),
#   'std_defense': np.float64(1.0321234114130793),
#   'overall_log_strength': np.float64(-0.21741931539817808),
#   'overall_abs_strength': np.float64(-0.20168463432817352),
#   'xg_vs_avg': np.float64(0.8466309585926362),
#   'xga_vs_avg': np.float64(1.0522407071106006),
#   'goal_diff_vs_avg': np.float64(-0.20560974851796443)},
#  {'team': 'QPR',
#   'std_attack': np.float64(0.7966218899278641),
#   'std_defense': np.float64(1.0750018232211864),
#   'overall_log_strength': np.float64(-0.2996974870136207),
#   'overall_abs_strength': np.float64(-0.27837993329332233),
#   'xg_vs_avg': np.float64(0.8121546981139447),
#   'xga_vs_avg': np.float64(1.0959548694499381),
#   'goal_diff_vs_avg': np.float64(-0.28380017133599345)},
#  {'team': 'Ipswich Town',
#   'std_attack': np.float64(0.9276067529034918),
#   'std_defense': np.float64(1.2117576237405205),
#   'overall_log_strength': np.float64(-0.26721928088994246),
#   'overall_abs_strength': np.float64(-0.2841508708370287),
#   'xg_vs_avg': np.float64(0.9456935490951804),
#   'xga_vs_avg': np.float64(1.2353762008999505),
#   'goal_diff_vs_avg': np.float64(-0.28968265180477004)},
#  {'team': 'Stoke City',
#   'std_attack': np.float64(0.7346095954273114),
#   'std_defense': np.float64(1.0192985323569774),
#   'overall_log_strength': np.float64(-0.32753076090745176),
#   'overall_abs_strength': np.float64(-0.284688936929666),
#   'xg_vs_avg': np.float64(0.7489332665210846),
#   'xga_vs_avg': np.float64(1.039165856121488),
#   'goal_diff_vs_avg': np.float64(-0.29023258960040343)},
#  {'team': 'Preston',
#   'std_attack': np.float64(0.7130435169520781),
#   'std_defense': np.float64(1.0428141421189971),
#   'overall_log_strength': np.float64(-0.3801357915013189),
#   'overall_abs_strength': np.float64(-0.329770625166919),
#   'xg_vs_avg': np.float64(0.7269466852144364),
#   'xga_vs_avg': np.float64(1.06313981269539),
#   'goal_diff_vs_avg': np.float64(-0.33619312748095354)},
#  {'team': 'Watford',
#   'std_attack': np.float64(0.8566311050081431),
#   'std_defense': np.float64(1.2346049696444463),
#   'overall_log_strength': np.float64(-0.36549895856316084),
#   'overall_abs_strength': np.float64(-0.3779738646363032),
#   'xg_vs_avg': np.float64(0.8733339935535818),
#   'xga_vs_avg': np.float64(1.2586688683694667),
#   'goal_diff_vs_avg': np.float64(-0.3853348748158849)},
#  {'team': 'Birmingham City',
#   'std_attack': np.float64(0.4393774748161924),
#   'std_defense': np.float64(0.8286488228236215),
#   'overall_log_strength': np.float64(-0.6344375548409935),
#   'overall_abs_strength': np.float64(-0.38927134800742913),
#   'xg_vs_avg': np.float64(0.4479446082629301),
#   'xga_vs_avg': np.float64(0.8448001601674017),
#   'goal_diff_vs_avg': np.float64(-0.3968555519044716)},
#  {'team': 'Sheffield Weds',
#   'std_attack': np.float64(0.9557880827900755),
#   'std_defense': np.float64(1.3580014476842575),
#   'overall_log_strength': np.float64(-0.3512331564023628),
#   'overall_abs_strength': np.float64(-0.4022133648941819),
#   'xg_vs_avg': np.float64(0.9744243682653144),
#   'xga_vs_avg': np.float64(1.3844704884778614),
#   'goal_diff_vs_avg': np.float64(-0.41004612021254694)},
#  {'team': 'Leicester City',
#   'std_attack': np.float64(0.8571219937461129),
#   'std_defense': np.float64(1.2642730484743283),
#   'overall_log_strength': np.float64(-0.3886723125114755),
#   'overall_abs_strength': np.float64(-0.40715105472821544),
#   'xg_vs_avg': np.float64(0.8738344538093619),
#   'xga_vs_avg': np.float64(1.2889152128485901),
#   'goal_diff_vs_avg': np.float64(-0.41508075903922825)},
#  {'team': 'Hull City',
#   'std_attack': np.float64(0.7419709553047432),
#   'std_defense': np.float64(1.2269988515691916),
#   'overall_log_strength': np.float64(-0.503016410136949),
#   'overall_abs_strength': np.float64(-0.4850278962644484),
#   'xg_vs_avg': np.float64(0.756438160730689),
#   'xga_vs_avg': np.float64(1.2509144981329507),
#   'goal_diff_vs_avg': np.float64(-0.4944763374022617)},
#  {'team': 'Portsmouth',
#   'std_attack': np.float64(0.8903732307110377),
#   'std_defense': np.float64(1.396925906620972),
#   'overall_log_strength': np.float64(-0.45038858518779834),
#   'overall_abs_strength': np.float64(-0.5065526759099344),
#   'xg_vs_avg': np.float64(0.9077340348535247),
#   'xga_vs_avg': np.float64(1.4241536307673968),
#   'goal_diff_vs_avg': np.float64(-0.5164195959138721)},
#  {'team': 'Swansea City',
#   'std_attack': np.float64(0.6950943384058916),
#   'std_defense': np.float64(1.2226353058399062),
#   'overall_log_strength': np.float64(-0.564716319781495),
#   'overall_abs_strength': np.float64(-0.5275409674340146),
#   'xg_vs_avg': np.float64(0.7086475273983094),
#   'xga_vs_avg': np.float64(1.246465901780111),
#   'goal_diff_vs_avg': np.float64(-0.5378183743818016)},
#  {'team': 'Oxford United',
#   'std_attack': np.float64(0.6977040975549419),
#   'std_defense': np.float64(1.301933926208783),
#   'overall_log_strength': np.float64(-0.6238109896865867),
#   'overall_abs_strength': np.float64(-0.6042298286538411),
#   'xg_vs_avg': np.float64(0.7113081725307686),
#   'xga_vs_avg': np.float64(1.3273101452563856),
#   'goal_diff_vs_avg': np.float64(-0.616001972725617)},
#  {'team': 'Southampton',
#   'std_attack': np.float64(0.7796815865067013),
#   'std_defense': np.float64(1.3900939494247844),
#   'overall_log_strength': np.float64(-0.5782409994440293),
#   'overall_abs_strength': np.float64(-0.6104123629180831),
#   'xg_vs_avg': np.float64(0.7948840868177639),
#   'xga_vs_avg': np.float64(1.417188510713368),
#   'goal_diff_vs_avg': np.float64(-0.622304423895604)},
#  {'team': 'Derby County',
#   'std_attack': np.float64(0.5800316992490239),
#   'std_defense': np.float64(1.2624679030460932),
#   'overall_log_strength': np.float64(-0.7777409815718859),
#   'overall_abs_strength': np.float64(-0.6824362037970694),
#   'xg_vs_avg': np.float64(0.5913413572438567),
#   'xga_vs_avg': np.float64(1.2870748830189982),
#   'goal_diff_vs_avg': np.float64(-0.6957335257751415)},
#  {'team': 'Luton Town',
#   'std_attack': np.float64(0.7112143461448313),
#   'std_defense': np.float64(1.460509676575563),
#   'overall_log_strength': np.float64(-0.7195668915873652),
#   'overall_abs_strength': np.float64(-0.7492953304307317),
#   'xg_vs_avg': np.float64(0.725081848604319),
#   'xga_vs_avg': np.float64(1.488976722965428),
#   'goal_diff_vs_avg': np.float64(-0.763894874361109)},
#  {'team': 'Cardiff City',
#   'std_attack': np.float64(0.770678498524619),
#   'std_defense': np.float64(1.5721455297124811),
#   'overall_log_strength': np.float64(-0.7129252510940574),
#   'overall_abs_strength': np.float64(-0.8014670311878621),
#   'xg_vs_avg': np.float64(0.7857054535230606),
#   'xga_vs_avg': np.float64(1.602788489799455),
#   'goal_diff_vs_avg': np.float64(-0.8170830362763944)},
#  {'team': 'Huddersfield',
#   'std_attack': np.float64(0.4085137884005941),
#   'std_defense': np.float64(1.3932923674486428),
#   'overall_log_strength': np.float64(-1.2268991676007777),
#   'overall_abs_strength': np.float64(-0.9847785790480488),
#   'xg_vs_avg': np.float64(0.4164791310516354),
#   'xga_vs_avg': np.float64(1.4204492696554138),
#   'goal_diff_vs_avg': np.float64(-1.0039701386037785)},
#  {'team': 'Rotherham Utd',
#   'std_attack': np.float64(0.31928019715081724),
#   'std_defense': np.float64(1.3511889754329198),
#   'overall_log_strength': np.float64(-1.4426711281409126),
#   'overall_abs_strength': np.float64(-1.0319087782821026),
#   'xg_vs_avg': np.float64(0.32550563248301323),
#   'xga_vs_avg': np.float64(1.3775252331531083),
#   'goal_diff_vs_avg': np.float64(-1.052019600670095)},
#  {'team': 'Plymouth Argyle',
#   'std_attack': np.float64(0.6759025698172894),
#   'std_defense': np.float64(1.7435052491026197),
#   'overall_log_strength': np.float64(-0.9476039386144901),
#   'overall_abs_strength': np.float64(-1.0676026792853304),
#   'xg_vs_avg': np.float64(0.6890815510908288),
#   'xga_vs_avg': np.float64(1.777488211080352),
#   'goal_diff_vs_avg': np.float64(-1.0884066599895232)}]
